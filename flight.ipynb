# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../DataSets/Flights.csv')

# %%
df
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0          1    1        4      WN     LAX      SLC       1625       58.0
# 1          1    1        4      UA     DEN      IAD        823        7.0
# 2          1    1        4      MQ     DFW      VPS       1305       36.0
# 3          1    1        4      AA     DFW      DCA       1555        7.0
# 4          1    1        4      WN     LAX      MCI       1720       48.0
# ...      ...  ...      ...     ...     ...      ...        ...        ...
# 58487     12   31        4      AA     SFO      DFW        515        5.0
# 58488     12   31        4      F9     LAS      SFO       1910       13.0
# 58489     12   31        4      OO     SFO      SBA       1846       -6.0
# 58490     12   31        4      WN     MSP      ATL        525       39.0
# 58491     12   31        4      OO     SFO      BOI        859        5.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# ...

# %%
df.AIRLINE.unique()
# Out:
# array(['WN', 'UA', 'MQ', 'AA', 'F9', 'EV', 'OO', 'NK', 'US', 'AS', 'DL',
#        'VX', 'B6', 'HA'], dtype=object)

# %%
df.describe()
# Out:
#               MONTH           DAY       WEEKDAY     SCHED_DEP     DEP_DELAY  \
# count  58492.000000  58492.000000  58492.000000  58492.000000  57659.000000
# mean       6.220646     15.702096      3.926862   1387.984836     10.921192
# std        3.358484      8.760846      1.995777    482.810792     36.146210
# min        1.000000      1.000000      1.000000      5.000000    -24.000000
# 25%        3.000000      8.000000      2.000000   1000.000000     -4.000000
# 50%        6.000000     16.000000      4.000000   1353.000000     -1.000000
# 75%        9.000000     23.000000      6.000000   1805.000000     10.000000
# max       12.000000     31.000000      7.000000   2359.000000   1194.000000
#
#            AIR_TIME          DIST     SCHED_ARR     ARR_DELAY      DIVERTED  \
# count  57474.000000  58492.000000  58492.000000  57474.000000  58492.000000
# mean     115.928576    872.900072   1549.399832      5.812315      0.002342
# ...

# %%
df.AIRLINE.value_counts()
# Out:
# AIRLINE
# DL    10601
# AA     8900
# WN     8418
# UA     7792
# OO     6588
# EV     5858
# MQ     3471
# US     1615
# NK     1516
# F9     1317
# VX      993
# AS      768
# B6      543
# HA      112
# Name: count, dtype: int64

# %%
df.groupby('AIRLINE')['WEEKDAY']

# %%
df.groupby('AIRLINE')['ARR_DELAY']

# %%
df.groupby('AIRLINE')['DEP_DELAY'].sum()
# Out:
# AIRLINE
# AA     98648.0
# AS      1389.0
# B6      7744.0
# DL     76502.0
# EV     52028.0
# F9     18718.0
# HA       288.0
# MQ     36933.0
# NK     29135.0
# OO     62399.0
# UA    124918.0
# US      6952.0
# VX      8803.0
# WN    105248.0
# Name: DEP_DELAY, dtype: float64

# %%
df.groupby('AIRLINE')['DEP_DELAY'].mean()
# Out:
# AIRLINE
# AA    11.274057
# AS     1.808594
# B6    14.287823
# DL     7.242450
# EV     9.092625
# F9    14.310398
# HA     2.571429
# MQ    11.094323
# NK    19.514401
# OO     9.662279
# UA    16.210485
# US     4.361355
# VX     8.918946
# WN    12.639366
# Name: DEP_DELAY, dtype: float64

# %%
df.AIR_TIME.mean()
# Out:
# 115.92857639976337

# %%
df[df.AIR_TIME>115]
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 1          1    1        4      UA     DEN      IAD        823        7.0
# 3          1    1        4      AA     DFW      DCA       1555        7.0
# 4          1    1        4      WN     LAX      MCI       1720       48.0
# 5          1    1        4      UA     IAH      SAN       1450        1.0
# 9          1    1        4      UA     IAH      SJC        925        3.0
# ...      ...  ...      ...     ...     ...      ...        ...        ...
# 58477     12   31        4      B6     DFW      BOS       1145       12.0
# 58481     12   31        4      UA     IAH      LAX       1433        1.0
# 58483     12   31        4      B6     PHX      BOS       2236      -12.0
# 58487     12   31        4      AA     SFO      DFW        515        5.0
# 58490     12   31        4      WN     MSP      ATL        525       39.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# ...

# %%
df.DIST.median()
# Out:
# 690.0

# %%
df[df.DIST>690]
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 1          1    1        4      UA     DEN      IAD        823        7.0
# 3          1    1        4      AA     DFW      DCA       1555        7.0
# 4          1    1        4      WN     LAX      MCI       1720       48.0
# 5          1    1        4      UA     IAH      SAN       1450        1.0
# 9          1    1        4      UA     IAH      SJC        925        3.0
# ...      ...  ...      ...     ...     ...      ...        ...        ...
# 58477     12   31        4      B6     DFW      BOS       1145       12.0
# 58481     12   31        4      UA     IAH      LAX       1433        1.0
# 58483     12   31        4      B6     PHX      BOS       2236      -12.0
# 58487     12   31        4      AA     SFO      DFW        515        5.0
# 58490     12   31        4      WN     MSP      ATL        525       39.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# ...

# %%
df[df.AIRLINE=='AA']
# Out:
#        MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 3          1    1        4      AA     DFW      DCA       1555        7.0
# 6          1    1        4      AA     DFW      MSY       1250       84.0
# 8          1    1        4      AA     ORD      STL       1845       -5.0
# 15         1    1        4      AA     DEN      DFW       1445       -6.0
# 26         1    1        4      AA     LAX      AUS       1430       33.0
# ...      ...  ...      ...     ...     ...      ...        ...        ...
# 58470     12   31        4      AA     DFW      FAT       1020       -3.0
# 58475     12   31        4      AA     IAH      CLT        710        1.0
# 58476     12   31        4      AA     DFW      TPA       1020       -3.0
# 58479     12   31        4      AA     DFW      ELP       1200        3.0
# 58487     12   31        4      AA     SFO      DFW        515        5.0
#
#        AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# ...

# %%
df.groupby('MONTH')['DIVERTED']

# %%
def time(x):
    if x>=1 and x<=400:
        return 'Mid_n'
    elif x>400 and x<=800:
        return 'early_m'
    elif x>800 and x<=1200:
        return 'morning'
    elif x>1200 and x<=1600:
        return 'afternoon'
    elif x>1600 and x<=2000:
        return 'evening'
    else:
        return 'night'

# %%
df['Category']=df.SCHED_DEP.apply(time)
df
# Out:
#        MONTH  DAY  WEEKDAY  AIRLINE  ORG_AIR  DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0          1    1        4       13        5       244       1625       58.0
# 1          1    1        4       10        1       127        823        7.0
# 2          1    1        4        7        2       268       1305       36.0
# 3          1    1        4        0        2        69       1555        7.0
# 4          1    1        4       13        5       163       1720       48.0
# ...      ...  ...      ...      ...      ...       ...        ...        ...
# 58487     12   31        4        0        9        71        515        5.0
# 58488     12   31        4        5        4       237       1910       13.0
# 58489     12   31        4        9        9       231       1846       -6.0
# 58490     12   31        4       13        6        15        525       39.0
# 58491     12   31        4        9        9        30        859        5.0
#
# ...

# %%
df['price']=df.DEP_DELAY.apply(time)
df
# Out:
#        MONTH  DAY  WEEKDAY  AIRLINE  ORG_AIR  DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0          1    1        4       13        5       244       1625       58.0
# 1          1    1        4       10        1       127        823        7.0
# 2          1    1        4        7        2       268       1305       36.0
# 3          1    1        4        0        2        69       1555        7.0
# 4          1    1        4       13        5       163       1720       48.0
# ...      ...  ...      ...      ...      ...       ...        ...        ...
# 58487     12   31        4        0        9        71        515        5.0
# 58488     12   31        4        5        4       237       1910       13.0
# 58489     12   31        4        9        9       231       1846       -6.0
# 58490     12   31        4       13        6        15        525       39.0
# 58491     12   31        4        9        9        30        859        5.0
#
# ...

# %%
df.groupby('AIRLINE')['CANCELLED'].sum().nlargest(10)
# Out:
# AIRLINE
# 0     154
# 7     152
# 4     146
# 9     142
# 10     93
# 13     93
# 3      38
# 8      25
# 11     21
# 5      10
# Name: CANCELLED, dtype: int64

# %%
df
# Out:
#        MONTH  DAY  WEEKDAY  AIRLINE  ORG_AIR  DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0          1    1        4       13        5       244       1625       58.0
# 1          1    1        4       10        1       127        823        7.0
# 2          1    1        4        7        2       268       1305       36.0
# 3          1    1        4        0        2        69       1555        7.0
# 4          1    1        4       13        5       163       1720       48.0
# ...      ...  ...      ...      ...      ...       ...        ...        ...
# 58487     12   31        4        0        9        71        515        5.0
# 58488     12   31        4        5        4       237       1910       13.0
# 58489     12   31        4        9        9       231       1846       -6.0
# 58490     12   31        4       13        6        15        525       39.0
# 58491     12   31        4        9        9        30        859        5.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()

# %%
df['AIRLINE']=labelencoder.fit_transform(df['AIRLINE'])
df['ORG_AIR']=labelencoder.fit_transform(df['ORG_AIR'])
df['DEST_AIR']=labelencoder.fit_transform(df['DEST_AIR'])
#df['Additional_Info']=labelencoder.fit_transform(df['Additional_Info'])

# %%
df
# Out:
#        MONTH  DAY  WEEKDAY  AIRLINE  ORG_AIR  DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0          1    1        4       13        5       244       1625       58.0
# 1          1    1        4       10        1       127        823        7.0
# 2          1    1        4        7        2       268       1305       36.0
# 3          1    1        4        0        2        69       1555        7.0
# 4          1    1        4       13        5       163       1720       48.0
# ...      ...  ...      ...      ...      ...       ...        ...        ...
# 58487     12   31        4        0        9        71        515        5.0
# 58488     12   31        4        5        4       237       1910       13.0
# 58489     12   31        4        9        9       231       1846       -6.0
# 58490     12   31        4       13        6        15        525       39.0
# 58491     12   31        4        9        9        30        859        5.0
#
# ...

# %%
pd.get_dummies(df,columns=["AIRLINE", "ORG_AIR", "DEST_AIR"] ,drop_first = True)
# Out:
#        MONTH  DAY  WEEKDAY  SCHED_DEP  DEP_DELAY  AIR_TIME  DIST  SCHED_ARR  \
# 0          1    1        4       1625       58.0      94.0   590       1905
# 1          1    1        4        823        7.0     154.0  1452       1333
# 2          1    1        4       1305       36.0      85.0   641       1453
# 3          1    1        4       1555        7.0     126.0  1192       1935
# 4          1    1        4       1720       48.0     166.0  1363       2225
# ...      ...  ...      ...        ...        ...       ...   ...        ...
# 58487     12   31        4        515        5.0     166.0  1464       1045
# 58488     12   31        4       1910       13.0      71.0   414       2050
# 58489     12   31        4       1846       -6.0      46.0   262       1956
# 58490     12   31        4        525       39.0     124.0   907        855
# 58491     12   31        4        859        5.0      73.0   522       1146
#
# ...
